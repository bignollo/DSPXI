# %% [markdown]
# # Plotly Chart Studio

# %% [markdown]
# Click [here](https://plot.ly/online-chart-maker/) to enter chart studio and login using your credentials.

# %% [markdown]
# # Online Docs

# %% [markdown]
# head to the [online](https://help.plot.ly/tutorials/) documentation. Lets have a quick look at the material

# %% [markdown]
# # Import our Chart

# %%
# !pip install plotly==2.4.1

# %%
# Import plotly package
import plotly

# Check plotly package version
plotly.__version__
# Out:
# '2.4.1'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

figure = py.get_figure("https://plot.ly/~fjvarasc/252")

import plotly.offline as py
py.init_notebook_mode(connected=True)
py.iplot(figure, filename='test')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="60ea2d85-743b-4b3c-8745-dc151f27a132" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '60ea2d85-743b-4b3c-8745-dc151f27a132',
# ...
