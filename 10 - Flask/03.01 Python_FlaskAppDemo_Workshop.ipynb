# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/fjvarasc/DSPXI/master/figures/python_logo.png)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Creating-a-Web-App-From-Scratch-Using-Python-Flask-and-SQLite-3" data-toc-modified-id="Creating-a-Web-App-From-Scratch-Using-Python-Flask-and-SQLite-3-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Creating a Web App From Scratch Using Python Flask and SQLite 3</a></span><ul class="toc-item"><li><span><a href="#Introduction-to-Python-Flask" data-toc-modified-id="Introduction-to-Python-Flask-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction to Python Flask</a></span></li><li><span><a href="#Setting-Up-Flask" data-toc-modified-id="Setting-Up-Flask-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Setting Up Flask</a></span></li><li><span><a href="#Creating-a-Home-Page" data-toc-modified-id="Creating-a-Home-Page-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Creating a Home Page</a></span></li><li><span><a href="#Creating-a-Signup-Page" data-toc-modified-id="Creating-a-Signup-Page-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Creating a Signup Page</a></span><ul class="toc-item"><li><span><a href="#Step-1:-Setting-Up-the-Database" data-toc-modified-id="Step-1:-Setting-Up-the-Database-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Step 1: Setting Up the Database</a></span></li><li><span><a href="#Step-2:-Create-a-Signup-interface" data-toc-modified-id="Step-2:-Create-a-Signup-interface-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Step 2: Create a Signup interface</a></span></li><li><span><a href="#Step-3:-Implement-a-Signup-method" data-toc-modified-id="Step-3:-Implement-a-Signup-method-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Step 3: Implement a Signup method</a></span></li><li><span><a href="#Step-4:-Create-a-Signup-request" data-toc-modified-id="Step-4:-Create-a-Signup-request-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Step 4: Create a Signup request</a></span></li><li><span><a href="#Step-5:-interact-with-database" data-toc-modified-id="Step-5:-interact-with-database-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Step 5: interact with database</a></span></li></ul></li></ul></li><li><span><a href="#Creating-the-Sign-In-Interface" data-toc-modified-id="Creating-the-Sign-In-Interface-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Creating the Sign-In Interface</a></span><ul class="toc-item"><li><span><a href="#Implementing-Sign-In" data-toc-modified-id="Implementing-Sign-In-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Implementing Sign-In</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Creating a Web App From Scratch Using Python Flask and SQLite 3
#
# We'll be using Python, Flask and MySQL to create a simple web application from scratch. It will be a simple bucket list application where users can register, sign in and create their bucket list. We'll be using Flask, a Python web application framework, to create our application, with MySQL as the back end.
#
#
# ### Introduction to Python Flask
#
# Flask is a Python framework for creating web applications. From the official site,
#
# >Flask is a microframework for Python based on Werkzeug, Jinja 2 and good intentions.
#
# When we think about Python, the de facto framework that comes to our mind is the Django framework. But from a Python beginner's perspective, Flask is easier to get started with, when compared to Django
#
# ### Setting Up Flask
#
# Setting up Flask is pretty simple and quick. With pip package manager, all we need to do is:
#
#
# `pip install flask`
#
# Once you're done with installing Flask, create a folder called FlaskApp. Navigate to the FlaskApp folder and create a file called app.py. Import the flask module and create an app using Flask as shown:

# %%
from flask import Flask
app = Flask(__name__)

#Now define the basic route / and its corresponding request handler:

@app.route("/")
def main():
    return "Welcome!"

if __name__ == "__main__":
    app.run(host='0.0.0.0',port=8080)

# %% [markdown]
# Point your browser to http://localhost:8080/ and you should have the welcome message.

# %% [markdown]
# ### Creating a Home Page
#
# First, when the application runs we should show a home page with the latest bucket list items added by users. So let's add our home page to our application folder.
#
# Flask looks for template files inside the `templates` folder. So navigate to the PythonApp folder and create a folder called templates. Inside templates, create a file called index_bucket.html. Open up index_bucket.html and add the following HTML:

# %% [markdown]
# ```html
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <title>Python Flask Bucket List App</title>
#
#
#     <!--link href="http://getbootstrap.com/dist/css/bootstrap.min.css" rel="stylesheet"-->
#     <!-- Latest compiled and minified CSS -->
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous">
#
#     <link href="https://getbootstrap.com/docs/3.3/examples/jumbotron-narrow/jumbotron-narrow.css" rel="stylesheet">
#
#
# </head>
#
# <body>
#
#     <div class="container">
#         <div class="header">
#             <nav>
#                 <ul class="nav nav-pills pull-right">
#                     <li role="presentation" class="active"><a href="#">Home</a>
#                     </li>
#                     <li role="presentation"><a href="#">Sign In</a>
#                     </li>
#                     <li role="presentation"><a href="showSignUp">Sign Up</a>
#                     </li>
#                 </ul>
#             </nav>
#             <h3 class="text-muted">Python Flask App</h3>
#         </div>
#
#         <div class="jumbotron">
#             <h1>Bucket List App</h1>
#             <p class="lead"></p>
#             <p><a class="btn btn-lg btn-success" href="showSignUp" role="button">Sign up today</a>
#             </p>
#         </div>
#
#         <div class="row marketing">
#             <div class="col-lg-6">
#                 <h4>Bucket List</h4>
#                 <p>Donec id elit non mi porta gravida at eget metus. Maecenas faucibus mollis interdum.</p>
#
#                 <h4>Bucket List</h4>
#                 <p>Morbi leo risus, porta ac consectetur ac, vestibulum at eros. Cras mattis consectetur purus sit amet fermentum.</p>
#
#                 <h4>Bucket List</h4>
#                 <p>Maecenas sed diam eget risus varius blandit sit amet non magna.</p>
#             </div>
#
#             <div class="col-lg-6">
#                 <h4>Bucket List</h4>
#                 <p>Donec id elit non mi porta gravida at eget metus. Maecenas faucibus mollis interdum.</p>
#
#                 <h4>Bucket List</h4>
#                 <p>Morbi leo risus, porta ac consectetur ac, vestibulum at eros. Cras mattis consectetur purus sit amet fermentum.</p>
#
#                 <h4>Bucket List</h4>
#                 <p>Maecenas sed diam eget risus varius blandit sit amet non magna.</p>
#             </div>
#         </div>
#
#         <footer class="footer">
#             <p>Powered by &copy; Company 2015</p>
#         </footer>
#
#     </div>
# </body>
#
# </html>
# ```

# %% [markdown]
# now let's import `render_template`, which we'll use to render the template files.
#
# ```python
# from flask import Flask, render_template
# ```
# Modify the main method to return the rendered template file.
#
# ```python
# def main():
#     return render_template('index_bucket.html')
# ```
#
# our code should look like below:

# %%
from flask import Flask, render_template
app = Flask(__name__)
app.secret_key = 'DSPXI2019'

@app.route("/")
def main():
    return render_template('index_bucket.html')

if __name__ == "__main__":
    app.run(host='0.0.0.0',port=8080)

# %% [markdown]
# Save the changes and restart the server. Point your browser to http://localhost:8080/ and you should have the below screen:

# %% [markdown]
# <img src='attachment:image.png' width="400">

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Creating a Signup Page
#
# #### Step 1: Setting Up the Database
#
# We'll be using SQLite as the back end. So let's create a database called BucketList:

# %%
import sqlite3

db_file="BucketList.db"
conn = sqlite3.connect(db_file)
print(sqlite3.version)
#let's create the cursor which will be using to execute queries on the dtabase
c = conn.cursor()

# %% [markdown]
# Once the database has been created, create  a table called tbl_user using the following script:

# %%
# Create table - tbl_user
sQuery = '''CREATE TABLE tbl_user (
  `user_id`  INTEGER PRIMARY KEY,
  `user_name` VARCHAR(45) NULL,
  `user_username` VARCHAR(45) NULL,
  `user_password` VARCHAR(45) NULL);'''
c.execute(sQuery);

# %%
#Good practice is close the connection if no longer used.
conn.close;

# %% [markdown]
# #### Step 2: Create a Signup interface
#
# Navigate to the templates directory and create an HTML file called `signup.html`. Add the following HTML code to `signup.html`:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Python Flask Bucket List App</title>
#
#     <!--link href="//getbootstrap.com/examples/jumbotron-narrow/jumbotron-narrow.css" rel="stylesheet"-->
#     <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet">
#     <link href="https://getbootstrap.com/docs/3.3/examples/jumbotron-narrow/jumbotron-narrow.css" rel="stylesheet">
#
#     <link href="../static/css/signup.css" rel="stylesheet">
#     <script src="../static/js/jquery-1.11.2.js"></script>
#     <script src="../static/js/signUp.js"></script>
#
#   </head>
#
#   <body>
#
#     <div class="container">
#       <div class="header">
#         <nav>
#           <ul class="nav nav-pills pull-right">
#             <li role="presentation" ><a href="showHome">Home</a></li>
#             <li role="presentation"><a href="#">Sign In</a></li>
#             <li role="presentation" class="active"><a href="#">Sign Up</a></li>
#           </ul>
#         </nav>
#         <h3 class="text-muted">Python Flask App</h3>
#       </div>
#
#       <div class="jumbotron">
#         <h1>Bucket List App</h1>
#         <form class="form-signin">
#         <label for="inputName" class="sr-only">Name</label>
#         <input type="name" name="inputName" id="inputName" class="form-control" placeholder="Name" required autofocus>
#         <label for="inputEmail" class="sr-only">Email address</label>
#         <input type="email" name="inputEmail" id="inputEmail" class="form-control" placeholder="Email address" required autofocus>
#         <label for="inputPassword" class="sr-only">Password</label>
#         <input type="password" name="inputPassword" id="inputPassword" class="form-control" placeholder="Password" required>
#
#         <button id="btnSignUp" class="btn btn-lg btn-primary btn-block" type="button">Sign up</button>
#       </form>
#       </div>
#
#
#
#       <footer class="footer">
#         <p>Powered by &copy; Teraworks 2019</p>
#       </footer>
#
#     </div>
#   </body>
# </html>
# ```

# %% [markdown]
# Also add the following CSS as signup.css to the static folder.

# %% [markdown]
# ```css
# body {
#   padding-top: 40px;
#   padding-bottom: 40px;
# }
#
# .form-signin {
#   max-width: 330px;
#   padding: 15px;
#   margin: 0 auto;
# }
# .form-signin .form-signin-heading,
# .form-signin .checkbox {
#   margin-bottom: 10px;
# }
# .form-signin .checkbox {
#   font-weight: normal;
# }
# .form-signin .form-control {
#   position: relative;
#   height: auto;
#   -webkit-box-sizing: border-box;
#      -moz-box-sizing: border-box;
#           box-sizing: border-box;
#   padding: 10px;
#   font-size: 16px;
# }
# .form-signin .form-control:focus {
#   z-index: 2;
# }
# .form-signin input[type="email"] {
#   margin-bottom: -1px;
#   border-bottom-right-radius: 0;
#   border-bottom-left-radius: 0;
# }
# .form-signin input[type="password"] {
#   margin-bottom: 10px;
#   border-top-left-radius: 0;
#   border-top-right-radius: 0;
# }
# ```

# %% [markdown]
# to our main app add another route called `showSignUp` to render the signup page once a request comes to `/showSignUp`, our app now have 2 routes.
#
# Save the changes and restart the server. Click on the Sign Up button on the home page and you should have the signup page as shown:
#
# ![image.png](attachment:image.png)

# %%
from flask import Flask, render_template
app = Flask(__name__)

@app.route("/")
def main():
    return render_template('index_bucket.html')

@app.route('/showSignUp')
def showSignUp():
    return render_template('signup.html')


if __name__ == "__main__":
    app.run(host='0.0.0.0',port=8080)

# %% [markdown]
# #### Step 3: Implement a Signup method
#
# Next, we need a server-side method for the UI to interact with the database. So navigate to PythonApp and create a new method called signUp and also add a route /signUp. Here is how it looks:
#
# ```python
# @app.route('/signUp')
# def signUp():
#     # create user code will be here !!
# ```
#
# We'll be using jQuery AJAX to post our signup data to the signUp method, so we'll specify the method in the route definition.
#
# ```python
# @app.route('/signUp',methods=['POST'])
# def signUp():
#     # create user code will be here !!
# ```
#
# In order to read the posted values we need to import request from Flask.
#
# ```python
# from flask import Flask, render_template, request
# ```
#
# Using request we can read the posted values as shown below:
#
# ```python
# @app.route('/signUp',methods=['POST'])
# def signUp():
#
#     # read the posted values from the UI
#     _name = request.form['inputName']
#     _email = request.form['inputEmail']
#     _password = request.form['inputPassword']
# ```
#
# Once the values are read, we'll simply check if they are valid and for the time being let's just return a simple message:
#
# ```python
# @app.route('/signUp',methods=['POST'])
# def signUp():
#
#     # read the posted values from the UI
#     _name = request.form['inputName']
#     _email = request.form['inputEmail']
#     _password = request.form['inputPassword']
#
#     # validate the received values
#     if _name and _email and _password:
#         return json.dumps({'html':'<span>All fields good !!</span>'})
#     else:
#         return json.dumps({'html':'<span>Enter the required fields</span>'})
# ```
# Also import json from Flask, since we are using it in the above code to return json data.
#
# ```python
# from flask import Flask, render_template, json, request
# ```

# %%
from flask import Flask, render_template
from flask import Flask, render_template, request
from flask import Flask, render_template, json, request

app = Flask(__name__)

@app.route("/")
def main():
    return render_template('index_bucket.html')

@app.route('/showSignUp')
def showSignUp():
    return render_template('signup.html')

@app.route('/signUp',methods=['POST'])
def signUp():

    # read the posted values from the UI
    _name = request.form['inputName']
    _email = request.form['inputEmail']
    _password = request.form['inputPassword']

    # validate the received values
    if _name and _email and _password:
        return json.dumps({'html':'<span>All fields good !!</span>'})
    else:
        return json.dumps({'html':'<span>Enter the required fields</span>'})

if __name__ == "__main__":
    app.run(host='0.0.0.0',port=8080)

# %% [markdown]
# #### Step 4: Create a Signup request
#
# We'll be using jQuery AJAX to send the signup request to the Python method. Add the jQuery code below inside static/js folder in a file called `signUp.js` and add a link to it from the signup page. Once jQuery has been included, we'll add a jQuery POST request when the user clicks the Sign Up button.
#
# So, let's attach the signup button click event as shown:
#
# ```jscript
# $(function() {
#     $('#btnSignUp').click(function() {
#
#         $.ajax({
#             url: '/signUp',
#             data: $('form').serialize(),
#             type: 'POST',
#             success: function(response) {
#                 console.log(response);
#             },
#             error: function(error) {
#                 console.log(error);
#             }
#         });
#     });
# });
# ```
# Save all the changes and restart the server. From the Sign Up page, fill in the details and click Sign Up. Check the browser console and you should have the below message:
#
# ```json
# {"html": "<span>All fields good !!</span>"}
# ```

# %% [markdown]
# #### Step 5: interact with database
#
# Once we have the name, email address and password, we can simply insert the user data into the database.
#
# To connect with the database, we'll be using SQLite3, which is a python extension.
#
# As we did ealier first, let's create the database connection:

# %%
import sqlite3
db_file="BucketList.db"
conn = sqlite3.connect(db_file)
print(sqlite3.version)

# %% [markdown]
# Once the connection is created, we'll require a cursor to insert the data. So, using `conn` connection,
# create a cursor.

# %%
#let's create the cursor which will be using to execute queries on the dtabase
cursor = conn.cursor()

# %% [markdown]
# Before add the new user, let's make our password salted using a helper provided by Werkzeug. Import the module into our app:
#
# ```python
# from werkzeug import generate_password_hash, check_password_hash
# ```
#
# Use the salting module to create the hashed password.
#
# ```python
# _hashed_password = generate_password_hash(_password)
# ```
#
# our modified code , should look like this:

# %%
from flask import Flask, render_template, request, json
from werkzeug import generate_password_hash, check_password_hash

application = Flask(__name__)

from sqlalchemy import create_engine
db_engine = create_engine("sqlite:///BucketList.db")

@application.route("/")
def main():
    return render_template('index_bucket.html')

@application.route('/signUp',methods=['POST'])
def signUp():

    # read the posted values from the UI
    _name = request.form['inputName']
    _email = request.form['inputEmail']
    _password = request.form['inputPassword']
    _hashed_password = generate_password_hash(_password)

    data = ('null', _name , _email , _password)
    db_engine.execute('INSERT INTO tbl_user (user_id,user_name,user_username,user_password) VALUES (%s, "%s", "%s", "%s");' % (data))
    
    # validate the received values, if the user was inserted correctly
    #return json.dumps({'message':'User created successfully !'})
    #else
    #return error to console and redirect to home page
    
@application.route('/showSignUp')
def showSignUp():
    return render_template('signup.html')

if __name__ == "__main__":
    application.run(host='0.0.0.0',port=8080)

# %%
# %load checkusers.py
